# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras import initializers
from tensorflow.keras import layers
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import os
import h5py
import csv
import skimage.io
from sklearn.model_selection import KFold
import glob
from zipfile import ZipFile
import cv2
import dlib
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image 
import matplotlib.pyplot as plt
import math
from zipfile import ZipFile
import PIL
from sklearn.model_selection import train_test_split

# %%
image_list =[]

anger = np.zeros((124))
happy = np.ones((128))
disgust = np.full((120),2)
fear = np.full((128),3)
sad = np.full((136),4)
surprise = np.full((120),5)
neutral = np.full((120),6)

labels = np.concatenate((anger,happy,disgust,fear,sad,surprise,neutral))

# %%
def plot_history(history):
  # function to plot accuracy vs epoch

  plt.plot(history.history['accuracy'], label='accuracy')
  plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')

# %%
def euclidean_distance(a, b):
  x1 = a[0]; y1 = a[1]
  x2 = b[0]; y2 = b[1]
  return math.sqrt(((x2 - x1) * (x2 - x1)) + ((y2 - y1) * (y2 - y1)))

# %%
file_name = "fe.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')

# Run 7 times while changing file_name
# Remove desktop.ini file from the particular folder which gets added after running this cell, before running the next cell (except for neutral)
# Out:
# Done

# %%
path_lists = []
matrix_lists = []
for folder_name in os.listdir('/content/neu'):
  path_1 = os.path.join('/content/neu', folder_name)
  for file_name in os.listdir(path_1):
    path_2 = os.path.join(path_1, file_name)
    if os.path.isfile(path_2):
      path_lists.append(path_2)
      image = cv2.imread(path_2)
      matrix_lists.append(image)
print(path_lists)

# Run 7 times while changing file_name
# Out:
# ['/content/neu/neutral/UY.NE3.136.jpg', '/content/neu/neutral/UY.NE1.134.jpg', '/content/neu/neutral/YM.NE2.50.jpg', '/content/neu/neutral/NM.NE3.94.jpg', '/content/neu/neutral/MK.NE1.113.jpg', '/content/neu/neutral/YM.NE1.49.jpg', '/content/neu/neutral/NM.NE2.93.jpg', '/content/neu/neutral/UY.NE2.135.jpg', '/content/neu/neutral/KL.NE2.156.jpg', '/content/neu/neutral/TM.NE1.177.jpg', '/content/neu/neutral/KL.NE1.155.jpg', '/content/neu/neutral/YM.NE3.51.jpg', '/content/neu/neutral/NA.NE2.200.jpg', '/content/neu/neutral/NM.NE1.92.jpg', '/content/neu/neutral/NA.NE3.201.jpg', '/content/neu/neutral/KM.NE3.3.jpg', '/content/neu/neutral/KM.NE2.2.jpg', '/content/neu/neutral/TM.NE2.178.jpg', '/content/neu/neutral/MK.NE3.115.jpg', '/content/neu/neutral/KA.NE3.28.jpg', '/content/neu/neutral/KA.NE2.27.jpg', '/content/neu/neutral/KR.NE3.73.jpg', '/content/neu/neutral/KR.NE1.71.jpg', '/content/neu/neutral/KR.NE2.72.jpg', '/content/neu/neutral/MK.NE2.114.jpg', '/content/neu/neutral/TM.NE3.179.jpg', '/content/neu/neutral/KM.NE1.1.jpg', '/content/neu/neutral/KL.NE3.157.jpg', '/content/neu/neutral/KA.NE1.26.jpg', '/content/neu/neutral/NA.NE1.199.jpg']

# %%
#face_cropping
gray_list=[]
cropped_img_list=[]
for img in matrix_lists:
  face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
  gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  gray_list.append(gray)
  faces=face_cascade.detectMultiScale(gray,1.3,5,minSize=(100,100))
  face_x, face_y, face_w, face_h = faces[0]
  cropped_img= gray[int(face_y):int(face_y+face_h), int(face_x):int(face_x+face_w)]
  cropped_img_list.append(cropped_img)
plt.imshow(cropped_img_list[0])
    
# Run 7 times

# %%
#face_allignment
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bunzip2 "shape_predictor_5_face_landmarks.dat.bz2"

# Run 7 times
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')
print(predictor)

# Run 7 times
# Out:
# --2020-07-07 18:14:35--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2.5’
#
# shape_predictor_5_f 100%[===================>]   5.44M  1.52MB/s    in 3.6s
#
# 2020-07-07 18:14:39 (1.52 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2.5’ saved [5706710/5706710]
#
# bunzip2: Output file shape_predictor_5_face_landmarks.dat already exists.
# <dlib.shape_predictor object at 0x7f81045517d8>

# %%
raw_img_list=[]
rotated_img_list=[]
for img in cropped_img_list:
  raw_img=img.copy()
  rects = detector(raw_img, 0)
  if len(rects) > 0:
    for rect in rects:
        x = rect.left()
        y = rect.top()
        w = rect.right()
        h = rect.bottom()
    landmarks = predictor(raw_img, rect)
    left_eye_left_x,left_eye_left_y,left_eye_right_x,left_eye_right_y=landmarks.part(2).x,landmarks.part(2).y,landmarks.part(3).x,landmarks.part(3).y
    right_eye_left_x,right_eye_left_y,right_eye_right_x,right_eye_right_y=landmarks.part(1).x,landmarks.part(1).y,landmarks.part(0).x,landmarks.part(0).y
    left_eye_center =((left_eye_left_x+left_eye_right_x)//2,(left_eye_left_y+left_eye_right_y)//2)
    right_eye_center =((right_eye_left_x+right_eye_right_x)//2,(right_eye_left_y+right_eye_right_y)//2)
    left_eye_x = left_eye_center[0]; left_eye_y = left_eye_center[1]
    right_eye_x = right_eye_center[0]; right_eye_y = right_eye_center[1]

    

    if left_eye_y < right_eye_y:
      point_3rd = (right_eye_x, left_eye_y)
      direction = 1 
      #rotate same direction to clock
    else:
      point_3rd = (left_eye_x, right_eye_y)
      direction = -1 #rotate inverse direction of clock

    a = euclidean_distance(left_eye_center, point_3rd)
    b = euclidean_distance(right_eye_center, left_eye_center)
    c = euclidean_distance(right_eye_center, point_3rd) 
    
    cos_a = (b*b + c*c - a*a)/(2*b*c) 
    angle = np.arccos(cos_a)
    angle = (angle * 180) / math.pi
    if direction == 1:
      angle = 90 - angle
    
    rotated_img = Image.fromarray(raw_img)


    
    rotated_img = np.array(rotated_img.rotate(direction * angle))
    rotated_img_list.append(rotated_img)
 
    

plt.imshow(rotated_img_list[0])

# Run 7 times

#histogram_equilization
histogram_list=[]
for img in rotated_img_list:
  
  equ = cv2.equalizeHist(img)
  histogram_list.append(equ)
plt.imshow(histogram_list[0])

# Run 7 times

# %%
#data_augmentation
import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util

def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def random_noise(image_array: ndarray):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# Run 7 times

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img 
random_rotation_list=[]
for img in histogram_list:
  random_img=random_rotation(img)
  random_rotation_list.append(random_img)
plt.imshow(random_rotation_list[0])

# Run 7 times

flip_list=[]
for img in histogram_list:
  flipped_img=horizontal_flip(img)
  flip_list.append(flipped_img)
plt.imshow(flip_list[0])

# Run 7 times

noise_list=[]
for img in histogram_list:
  noise_image=random_noise(img)
  noise_list.append(noise_image)
plt.imshow(noise_list[0]) 

# Run 7 times

final_list=[]
for img in histogram_list:
  final_list.append(img)

for img in random_rotation_list:
  final_list.append(img)

for img in flip_list:
  final_list.append(img)

for img in noise_list:
  final_list.append(img)

# Run 7 times

# %%
for img in final_list:
  image_list.append(img)

# Run 7 times

# %%
print(len(image_list))
# Out:
# 876

# %%
img_list = []
for img in image_list:
  img_list.append(img)

# %%
for i in range((len(image_list))):
  image_list[i] = np.resize(image_list[i], (128,128))

# %%
data_x = np.asarray(image_list) #if dtype=np.float32 gives an error, remove it.

# %%
print(data_x.shape)
# Out:
# (876, 128, 128)

# %%
initializer = tf.keras.initializers.GlorotUniform(seed=None)

# %%
#check input shape
def cnn_model(input_shape=(128,128,1), num_classes=7):

  model = tf.keras.models.Sequential([tf.keras.layers.Dense(3, kernel_initializer=initializer),
                                      tf.keras.layers.Conv2D(32, (5, 5), activation='relu', input_shape=(128, 128,1)),
                                      tf.keras.layers.MaxPooling2D((2, 2), strides=2),
                                      tf.keras.layers.Conv2D(64, (5, 5), activation='relu'),
                                      tf.keras.layers.MaxPooling2D((2, 2), strides=2),
                                      tf.keras.layers.Flatten(),
                                      tf.keras.layers.Dropout(0.25),
                                      tf.keras.layers.Dense(7, activation=tf.nn.softmax)])
  
  return model  
  # This is the simple CNN model as was designed in the paper

# %%
def cnn_model_custom(input_shape=(128, 128, 1), num_classes=7):

  model = tf.keras.models.Sequential([tf.keras.layers.Dense(3, kernel_initializer=initializer),
                                      tf.keras.layers.Conv2D(6, (5, 5), activation='relu', input_shape=(128, 128, 1)),
                                      tf.keras.layers.MaxPooling2D((2, 2)),
                                      tf.keras.layers.Conv2D(16, (5, 5), activation='relu'),
                                      tf.keras.layers.MaxPooling2D((2, 2)),
                                      tf.keras.layers.Conv2D(120, (5, 5), activation='relu'),
                                      tf.keras.layers.Dropout(0.25),
                                      tf.keras.layers.Flatten(),
                                      tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                      tf.keras.layers.Dropout(0.4),
                                      tf.keras.layers.Dense(7, activation=tf.nn.softmax)])
  
  return model
  
  # This is the second CNN model as is built on the culmination of one other paper which yielded fantastic results for JAFFE dataset and one image classification stackoverflow link

# %%
# This block is to be able to use the momentum optimizer while compiling CNN

lr = 0.0001
momentum = 0.1
Momentum = tf.compat.v1.train.MomentumOptimizer(
    lr, momentum, name='Momentum', use_locking=False, use_nesterov=True
)

# Momentum optimizer, Nesterov can be used true or false depending on validation data

# %%
x_train, x_test, y_train, y_test = train_test_split(data_x, labels, train_size=0.75, shuffle=True)

x_train = x_train.reshape(x_train.shape[0], 128, 128, 1)
x_test = x_test.reshape(x_test.shape[0], 128, 128, 1)
y_train = y_train.reshape(y_train.shape[0], 1)
y_test = y_test.reshape(y_test.shape[0], 1)

print(x_train.shape)
print(y_test.shape)
# Out:
# (657, 128, 128, 1)
# (219, 1)

# %%
model = cnn_model()
lr = 0.0001

model.compile(optimizer = tf.keras.optimizers.Adam(lr=lr),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10,
                    validation_data=(x_test, y_test))
plot_history(history)
model.summary()
# Out:
# Epoch 1/10
# 21/21 [==============================] - 27s 1s/step - loss: 17.6178 - accuracy: 0.1507 - val_loss: 9.3198 - val_accuracy: 0.1735
# Epoch 2/10
# 21/21 [==============================] - 30s 1s/step - loss: 4.8775 - accuracy: 0.2359 - val_loss: 3.3937 - val_accuracy: 0.2420
# Epoch 3/10
# 21/21 [==============================] - 26s 1s/step - loss: 2.6344 - accuracy: 0.2953 - val_loss: 2.4347 - val_accuracy: 0.2877
# Epoch 4/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.9687 - accuracy: 0.3592 - val_loss: 2.0736 - val_accuracy: 0.3288
# Epoch 5/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.6325 - accuracy: 0.4353 - val_loss: 2.0813 - val_accuracy: 0.3470
# Epoch 6/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.4711 - accuracy: 0.4855 - val_loss: 2.2031 - val_accuracy: 0.3288
# Epoch 7/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.3264 - accuracy: 0.5723 - val_loss: 2.1179 - val_accuracy: 0.3744
# Epoch 8/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.2263 - accuracy: 0.6134 - val_loss: 2.2493 - val_accuracy: 0.3014
# Epoch 9/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.1727 - accuracy: 0.6377 - val_loss: 2.2172 - val_accuracy: 0.3516
# Epoch 10/10
# 21/21 [==============================] - 26s 1s/step - loss: 1.1152 - accuracy: 0.6560 - val_loss: 2.2460 - val_accuracy: 0.3607
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_22 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_23 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_10 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_12 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_23 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=None)
kf.get_n_splits(data_x)
print(kf)
lr = 0.0001
model = cnn_model()
model.compile(optimizer = tf.keras.optimizers.Adam(lr=lr),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
for train_index, test_index in kf.split(data_x, labels):
  X_train, X_test = data_x[train_index], data_x[test_index]
  Y_train, Y_test = labels[train_index], labels[test_index]
  X_train = X_train.reshape(X_train.shape[0], 128, 128, 1)
  X_test = X_test.reshape(X_test.shape[0], 128, 128, 1)
  Y_train = Y_train.reshape(Y_train.shape[0], 1)
  Y_test = Y_test.reshape(Y_test.shape[0], 1)

  model.fit(X_train, Y_train, epochs=10,
            validation_data=(X_test, Y_test))
  plot_history(history)
  model.summary()
# Out:
# KFold(n_splits=10, random_state=None, shuffle=True)
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 12.9895 - accuracy: 0.1536 - val_loss: 4.5716 - val_accuracy: 0.2159
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 4.4762 - accuracy: 0.2234 - val_loss: 2.4846 - val_accuracy: 0.2386
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 2.2692 - accuracy: 0.3198 - val_loss: 2.2191 - val_accuracy: 0.2500
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.7574 - accuracy: 0.4023 - val_loss: 1.9384 - val_accuracy: 0.2841
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.5913 - accuracy: 0.4937 - val_loss: 1.9269 - val_accuracy: 0.2955
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.4278 - accuracy: 0.5457 - val_loss: 1.9580 - val_accuracy: 0.3068
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.3425 - accuracy: 0.5863 - val_loss: 1.8571 - val_accuracy: 0.3182
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.2447 - accuracy: 0.5850 - val_loss: 1.9772 - val_accuracy: 0.2386
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.1919 - accuracy: 0.6129 - val_loss: 1.9008 - val_accuracy: 0.3182
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.1447 - accuracy: 0.6307 - val_loss: 1.9882 - val_accuracy: 0.2500
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.2372 - accuracy: 0.5596 - val_loss: 1.0240 - val_accuracy: 0.6364
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.1793 - accuracy: 0.5622 - val_loss: 1.0248 - val_accuracy: 0.6591
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.0986 - accuracy: 0.6015 - val_loss: 1.0691 - val_accuracy: 0.6250
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.0647 - accuracy: 0.6206 - val_loss: 1.0481 - val_accuracy: 0.6250
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.0307 - accuracy: 0.6421 - val_loss: 1.0200 - val_accuracy: 0.6364
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.0327 - accuracy: 0.6383 - val_loss: 1.0714 - val_accuracy: 0.6136
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 1.0026 - accuracy: 0.6371 - val_loss: 1.0913 - val_accuracy: 0.6023
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9809 - accuracy: 0.6548 - val_loss: 1.0732 - val_accuracy: 0.5455
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9727 - accuracy: 0.6662 - val_loss: 1.1286 - val_accuracy: 0.5909
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9738 - accuracy: 0.6713 - val_loss: 1.0902 - val_accuracy: 0.6023
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9780 - accuracy: 0.6510 - val_loss: 0.8419 - val_accuracy: 0.6932
# Epoch 2/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.9813 - accuracy: 0.6396 - val_loss: 0.8838 - val_accuracy: 0.6250
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9385 - accuracy: 0.6599 - val_loss: 0.8757 - val_accuracy: 0.7045
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.9159 - accuracy: 0.6764 - val_loss: 0.8384 - val_accuracy: 0.6818
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8925 - accuracy: 0.6637 - val_loss: 0.8361 - val_accuracy: 0.7045
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8850 - accuracy: 0.6739 - val_loss: 0.8414 - val_accuracy: 0.6932
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8850 - accuracy: 0.6713 - val_loss: 0.8526 - val_accuracy: 0.6818
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8676 - accuracy: 0.6802 - val_loss: 0.8376 - val_accuracy: 0.7045
# Epoch 9/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.8571 - accuracy: 0.6713 - val_loss: 0.8547 - val_accuracy: 0.6705
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8496 - accuracy: 0.6865 - val_loss: 0.8588 - val_accuracy: 0.6364
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8660 - accuracy: 0.6739 - val_loss: 0.6885 - val_accuracy: 0.7955
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8642 - accuracy: 0.6751 - val_loss: 0.6951 - val_accuracy: 0.7614
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8556 - accuracy: 0.6764 - val_loss: 0.6898 - val_accuracy: 0.7727
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8464 - accuracy: 0.6802 - val_loss: 0.7143 - val_accuracy: 0.7614
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8393 - accuracy: 0.6878 - val_loss: 0.6880 - val_accuracy: 0.7500
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8585 - accuracy: 0.6815 - val_loss: 0.7058 - val_accuracy: 0.7614
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8846 - accuracy: 0.6827 - val_loss: 0.7090 - val_accuracy: 0.7614
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8354 - accuracy: 0.6789 - val_loss: 0.6924 - val_accuracy: 0.7500
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8199 - accuracy: 0.6954 - val_loss: 0.7116 - val_accuracy: 0.7500
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8155 - accuracy: 0.7005 - val_loss: 0.6996 - val_accuracy: 0.7500
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.8031 - accuracy: 0.7069 - val_loss: 0.7506 - val_accuracy: 0.7500
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.8093 - accuracy: 0.6942 - val_loss: 0.7717 - val_accuracy: 0.7159
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7991 - accuracy: 0.7234 - val_loss: 0.7644 - val_accuracy: 0.7159
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7880 - accuracy: 0.7069 - val_loss: 0.7661 - val_accuracy: 0.7159
# Epoch 5/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7797 - accuracy: 0.7170 - val_loss: 0.7539 - val_accuracy: 0.7159
# Epoch 6/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7757 - accuracy: 0.7221 - val_loss: 0.7644 - val_accuracy: 0.7386
# Epoch 7/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7686 - accuracy: 0.7221 - val_loss: 0.7582 - val_accuracy: 0.7159
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7651 - accuracy: 0.7272 - val_loss: 0.7582 - val_accuracy: 0.7159
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7593 - accuracy: 0.7170 - val_loss: 0.7599 - val_accuracy: 0.7159
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7605 - accuracy: 0.7373 - val_loss: 0.7614 - val_accuracy: 0.7045
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7590 - accuracy: 0.7411 - val_loss: 0.7248 - val_accuracy: 0.7386
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7578 - accuracy: 0.7297 - val_loss: 0.7254 - val_accuracy: 0.7159
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7509 - accuracy: 0.7437 - val_loss: 0.7446 - val_accuracy: 0.6932
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7434 - accuracy: 0.7360 - val_loss: 0.7329 - val_accuracy: 0.7614
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7414 - accuracy: 0.7487 - val_loss: 0.7317 - val_accuracy: 0.7386
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7356 - accuracy: 0.7398 - val_loss: 0.7408 - val_accuracy: 0.7614
# Epoch 7/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7353 - accuracy: 0.7386 - val_loss: 0.7255 - val_accuracy: 0.7159
# Epoch 8/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7397 - accuracy: 0.7411 - val_loss: 0.7601 - val_accuracy: 0.6932
# Epoch 9/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.7414 - accuracy: 0.7373 - val_loss: 0.7508 - val_accuracy: 0.7273
# Epoch 10/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.7257 - accuracy: 0.7538 - val_loss: 0.7470 - val_accuracy: 0.7273
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7184 - accuracy: 0.7490 - val_loss: 0.7171 - val_accuracy: 0.7816
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7377 - accuracy: 0.7452 - val_loss: 0.7302 - val_accuracy: 0.7701
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7430 - accuracy: 0.7465 - val_loss: 0.7057 - val_accuracy: 0.7701
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7171 - accuracy: 0.7478 - val_loss: 0.7247 - val_accuracy: 0.7701
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7127 - accuracy: 0.7376 - val_loss: 0.7575 - val_accuracy: 0.7586
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.7128 - accuracy: 0.7529 - val_loss: 0.7637 - val_accuracy: 0.7586
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6980 - accuracy: 0.7414 - val_loss: 0.7940 - val_accuracy: 0.7241
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6901 - accuracy: 0.7579 - val_loss: 0.7215 - val_accuracy: 0.7586
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6886 - accuracy: 0.7681 - val_loss: 0.7265 - val_accuracy: 0.7586
# Epoch 10/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6836 - accuracy: 0.7579 - val_loss: 0.7345 - val_accuracy: 0.7701
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6875 - accuracy: 0.7681 - val_loss: 0.6374 - val_accuracy: 0.8391
# Epoch 2/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6811 - accuracy: 0.7605 - val_loss: 0.6505 - val_accuracy: 0.8161
# Epoch 3/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6878 - accuracy: 0.7605 - val_loss: 0.6708 - val_accuracy: 0.8161
# Epoch 4/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6708 - accuracy: 0.7719 - val_loss: 0.6458 - val_accuracy: 0.8161
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6903 - accuracy: 0.7516 - val_loss: 0.6332 - val_accuracy: 0.8276
# Epoch 6/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6744 - accuracy: 0.7643 - val_loss: 0.6483 - val_accuracy: 0.8161
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6622 - accuracy: 0.7706 - val_loss: 0.6623 - val_accuracy: 0.8046
# Epoch 8/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6501 - accuracy: 0.7744 - val_loss: 0.6525 - val_accuracy: 0.8391
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6463 - accuracy: 0.7769 - val_loss: 0.6519 - val_accuracy: 0.8276
# Epoch 10/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.6388 - accuracy: 0.7681 - val_loss: 0.6622 - val_accuracy: 0.8161
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6370 - accuracy: 0.7782 - val_loss: 0.6477 - val_accuracy: 0.7931
# Epoch 2/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6347 - accuracy: 0.7706 - val_loss: 0.6459 - val_accuracy: 0.7816
# Epoch 3/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6295 - accuracy: 0.7820 - val_loss: 0.6372 - val_accuracy: 0.7586
# Epoch 4/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6195 - accuracy: 0.7858 - val_loss: 0.6643 - val_accuracy: 0.7701
# Epoch 5/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6116 - accuracy: 0.7807 - val_loss: 0.6391 - val_accuracy: 0.7586
# Epoch 6/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6209 - accuracy: 0.7757 - val_loss: 0.6623 - val_accuracy: 0.7471
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6027 - accuracy: 0.7858 - val_loss: 0.6650 - val_accuracy: 0.7356
# Epoch 8/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6181 - accuracy: 0.7833 - val_loss: 0.6516 - val_accuracy: 0.7586
# Epoch 9/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6044 - accuracy: 0.7934 - val_loss: 0.6854 - val_accuracy: 0.7241
# Epoch 10/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6080 - accuracy: 0.7845 - val_loss: 0.6951 - val_accuracy: 0.7241
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.5821 - accuracy: 0.7947 - val_loss: 0.7150 - val_accuracy: 0.7471
# Epoch 2/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.5898 - accuracy: 0.7845 - val_loss: 0.7423 - val_accuracy: 0.7241
# Epoch 3/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.5830 - accuracy: 0.7921 - val_loss: 0.7274 - val_accuracy: 0.7241
# Epoch 4/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.5828 - accuracy: 0.8061 - val_loss: 0.7456 - val_accuracy: 0.7356
# Epoch 5/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.5786 - accuracy: 0.8010 - val_loss: 0.7431 - val_accuracy: 0.7816
# Epoch 6/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6368 - accuracy: 0.7871 - val_loss: 0.7617 - val_accuracy: 0.7356
# Epoch 7/10
# 25/25 [==============================] - 30s 1s/step - loss: 0.6128 - accuracy: 0.7871 - val_loss: 0.9269 - val_accuracy: 0.7241
# Epoch 8/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6136 - accuracy: 0.7947 - val_loss: 0.7653 - val_accuracy: 0.7241
# Epoch 9/10
# 25/25 [==============================] - 34s 1s/step - loss: 0.6303 - accuracy: 0.7896 - val_loss: 0.7785 - val_accuracy: 0.7241
# Epoch 10/10
# 25/25 [==============================] - 31s 1s/step - loss: 0.6074 - accuracy: 0.8061 - val_loss: 0.8194 - val_accuracy: 0.7356
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             multiple                  6
# _________________________________________________________________
# conv2d_24 (Conv2D)           multiple                  2432
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_25 (Conv2D)           multiple                  51264
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling multiple                  0
# _________________________________________________________________
# flatten_11 (Flatten)         multiple                  0
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_25 (Dense)             multiple                  376775
# =================================================================
# Total params: 430,477
# Trainable params: 430,477
# Non-trainable params: 0
# _________________________________________________________________
